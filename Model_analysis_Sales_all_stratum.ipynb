# %%
# %run Regression_model_functions.ipynb
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', True)
from sklearn.model_selection import train_test_split
from pprint import pprint
# Out:
# python3 is /home/ec2-user/anaconda3/envs/python3/bin/python3
# /bin/sh: /Users/joseheredia/anaconda3/bin/python3: No such file or directory
# Imports finished...

# %%
def data_split(df):
    # Data split
    x = df.drop('price_m2',axis=1)
    y = df['price_m2']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
    return x_train, x_test, y_train, y_test

# %%
def execute_analysis(data_df, x_column_names):
    x_train, x_test, y_train, y_test = data_split(data_df)
    df = pd.DataFrame()
    df = pd.concat([df,xgboost(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    df = pd.concat([df,gradientboost_regressor(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    df = pd.concat([df,randomforest_regressor(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    df = pd.concat([df,linear_regression(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    # results = pd.concat([df,ransac(x_train, y_train, x_test, y_test)], ignore_index=True)
    df = pd.concat([df,ridge(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    # df = pd.concat([df,elasticnet(x_train, y_train, x_test, y_test)], ignore_index=True)
    # results = pd.concat([df,linearsvr(x_train, y_train, x_test, y_test)], ignore_index=True)
    # results = pd.concat([df,bayesianridge(x_train, y_train, x_test, y_test)], ignore_index=True)
    df = pd.concat([df,lasso(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    df = pd.concat([df,decisiontree_regressor(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    # df = pd.concat([df,sgd_regressor(x_train, y_train, x_test, y_test)], ignore_index=True)
    # df = pd.concat([df,huber_regressor(x_train, y_train, x_test, y_test)], ignore_index=True)
    # df = pd.concat([df,theilsen_regressor(x_train, y_train, x_test, y_test)], ignore_index=True)
    return df

def execute_analysis_v2():
    df = pd.DataFrame()
    df = pd.concat([df,knn_regressor(x_train, y_train, x_test, y_test, x_column_names)], ignore_index=True)
    return df

# %%
display(data_df.head())

# %%
# Analysis 1: Remove redundant columns
# data_df = pd.read_csv('Data/20230409_Sales_HousesApartments_Bogota_Stratum4_price_and_pricem2.csv')
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
# data_df.drop('price', axis=1, inplace=True)
data_df.drop(columns=['garages','baths'], inplace=True)
# data_df.dropna(inplace=True)
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v1 = execute_analysis()

# %%
print("--------------- Results Analysis 1 ---------------")
display(results_v1)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 1 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.52  [(lat, 0.008474376), (lng, 0.008552799), (stra...
# 1  0.99     0.71  0.72  [(lat, 0.18039761538145277), (lng, 0.059370682...
# 2  0.83      0.8  0.54  [(lat, 0.20379056865517575), (lng, 0.127922673...
# 3  1.21     0.56  0.92  [(lat, -13.602169471232248), (lng, 9.807939435...
# 4  1.21     0.56  0.92  [(lat, -13.30296813333818), (lng, 9.3489888876...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03233762...
# 6  1.06     0.66  0.74  [(lat, 0.17291698785976656), (lng, 0.093467557...
# --------------------- Finish ---------------------

# %%
# Analysis 2: Reduce DF
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
data_df.drop(columns=['garages','baths', 'rooms'], inplace=True)
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v2 = execute_analysis()

# %%
print("--------------- Results Analysis 2 ---------------")
display(results_v2)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 2 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.82      0.8  0.52  [(lat, 0.008902231), (lng, 0.009582237), (stra...
# 1  0.99     0.71  0.72  [(lat, 0.19836401330110703), (lng, 0.086731604...
# 2  0.83     0.79  0.54  [(lat, 0.21717420212173938), (lng, 0.139200193...
# 3  1.23     0.54  0.94  [(lat, -14.87610972922266), (lng, 11.913862575...
# 4  1.23     0.54  0.94  [(lat, -14.55304518806653), (lng, 11.400205818...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03233762...
# 6  1.06     0.67  0.73  [(lat, 0.22737990249150836), (lng, 0.216676543...
# --------------------- Finish ---------------------

# %%
# Analysis 3: Full DF
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v3 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 3 ---------------")
display(results_v3)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 3 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.79     0.81   0.5  [(lat, 0.008155236), (lng, 0.00788017), (strat...
# 1  0.96     0.72   0.7  [(lat, 0.17124220475818608), (lng, 0.056540217...
# 2  0.81      0.8  0.53  [(lat, 0.1919280970846476), (lng, 0.1136694223...
# 3  1.18     0.58  0.89  [(lat, -14.192225668815261), (lng, 9.079787013...
# 4  1.18     0.58  0.89  [(lat, -13.8916957464668), (lng, 8.63802336245...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03233762...
# 6  1.04     0.67  0.73  [(lat, 0.21866706682135795), (lng, 0.110963267...
# --------------------- Finish ---------------------

# %%
# Analysis 4: Reduce DF
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
data_df.drop(columns=['garages'], inplace=True)
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v4 = execute_analysis()

# %%
print("--------------- Results Analysis 4 ---------------")
display(results_v4)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 4 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.51  [(lat, 0.008302038), (lng, 0.008272111), (stra...
# 1  0.98     0.71  0.72  [(lat, 0.1797912409855127), (lng, 0.0585074779...
# 2  0.82      0.8  0.54  [(lat, 0.20017465597652503), (lng, 0.123287867...
# 3  1.21     0.56  0.92  [(lat, -13.726604748054763), (lng, 9.387024902...
# 4  1.21     0.56  0.92  [(lat, -13.430162033585953), (lng, 8.939748479...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03233762...
# 6  1.05     0.67  0.73  [(lat, 0.2753599306908155), (lng, 0.1827236560...
# --------------------- Finish ---------------------

# %%
# Analysis 5: Full DF with nbrs categories
data_df = pd.read_csv('Data/Raw_data_sales_full_incl_nbrs.csv')
data_df = pd.get_dummies(data_df, columns=["nbr"])
display(data_df.head())
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v5 = execute_analysis()

# %%
print("--------------- Results Analysis 5 ---------------")
display(results_v5)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 5 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#           RMSE            R2 Score        MAE
# 0         0.81                 0.8       0.51  \
# 1         0.98                0.72       0.71
# 2         0.83                 0.8       0.53
# 3  50550945.86  -760812003596142.2  526642.72
# 4         1.09                0.65        0.8
# 5          1.8                0.03       1.42
# 6          1.2                0.57       0.88
#
#                                   Feature Importance
# 0  [(lat, 0.0014683057), (lng, 0.0013126521), (st...
# 1  [(lat, 0.15304052444917432), (lng, 0.040823694...
# 2  [(lat, 0.17189347737261537), (lng, 0.093953298...
# 3  [(lat, -11.898285157811653), (lng, 4.070843233...
# 4  [(lat, -4.665462400327313), (lng, 4.6211249325...
# 5  [(lat, -0.0), (lng, 0.0), (stratum, 0.03553441...
# 6  [(lat, 0.0620028496770391), (lng, 0.0405665845...
# --------------------- Finish ---------------------

# %%
# Analysis 6: Only using lat and lng
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
data_df['lat'] = np.radians(data_df['lat'])
data_df['lng'] = np.radians(data_df['lng'])
data_df = data_df[['lat', 'lng', 'price_m2']]
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v6 = execute_analysis_v2()

# %%
print("--------------- Results Analysis 6 ---------------")
display(results_v6)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 6 ---------------
#            Model                                         Parameters  RMSE
# 0  KNN_Regressor  {'algorithm': 'auto', 'metric': 'haversine', '...  1.19  \
#
#   R2 Score   MAE Feature Importance
# 0     0.58  0.81               None
# --------------------- Finish ---------------------

# %%
# Analysis 7: use Analysis 3 with lat and long converted to radians
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs.csv')
data_df['lat'] = np.radians(data_df['lat'])
data_df['lng'] = np.radians(data_df['lng'])
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v7 = execute_analysis()

# %%
print("--------------- Results Analysis 7 ---------------")
display(results_v7)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 7 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.79     0.81   0.5  [(lat, 0.008091328), (lng, 0.0077255634), (str...
# 1  0.96     0.72   0.7  [(lat, 0.17490380117600168), (lng, 0.054974880...
# 2  0.81      0.8  0.53  [(lat, 0.19439345056610285), (lng, 0.115484131...
# 3  1.18     0.58  0.89  [(lat, -813.1546327209976), (lng, 520.23347472...
# 4  1.27     0.52  0.97  [(lat, -16.625051119468836), (lng, -0.58166287...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03233762...
# 6  1.06     0.67  0.73  [(lat, 0.17390327834962938), (lng, 0.202061245...
# --------------------- Finish ---------------------

# %%
# Analysis 8: use Analysis 3 now include information about police stations
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police.csv')
x_train, x_test, y_train, y_test = data_split(data_df)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v8 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 8 ---------------")
display(results_v8)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 8 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.51  [(lat, 0.008195336), (lng, 0.00775533), (strat...
# 1  0.97     0.72  0.71  [(lat, 0.1692459525611627), (lng, 0.0534089487...
# 2  0.83     0.79  0.54  [(lat, 0.1737938378095084), (lng, 0.0947531990...
# 3  1.19     0.57   0.9  [(lat, -12.833435836845009), (lng, 8.704907487...
# 4  1.19     0.57   0.9  [(lat, -12.492195524036651), (lng, 8.264051057...
# 5  1.79     0.04  1.41  [(lat, -0.0), (lng, 0.0), (stratum, 0.04267298...
# 6  1.07     0.66  0.74  [(lat, 0.24541931933164665), (lng, 0.083470827...
# --------------------- Finish ---------------------

# %%
# Analysis 9: use Analysis 3 now include information about police stations (1 column)
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police.csv')
data_df.drop('police_stations_within_800m',axis=1,inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v9 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 9 ---------------")
display(results_v9)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 9 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.51  [(lat, 0.008324767), (lng, 0.007870808), (stra...
# 1  0.97     0.72  0.71  [(lat, 0.1706513628290649), (lng, 0.0525613705...
# 2  0.83     0.79  0.54  [(lat, 0.17829734752060164), (lng, 0.099733360...
# 3  1.19     0.57   0.9  [(lat, -13.557264313807115), (lng, 9.152461414...
# 4  1.19     0.57   0.9  [(lat, -13.245077842620107), (lng, 8.716916102...
# 5  1.79     0.04  1.41  [(lat, -0.0), (lng, 0.0), (stratum, 0.04267298...
# 6  1.07     0.66  0.74  [(lat, 0.1470323121068443), (lng, 0.0761777249...
# --------------------- Finish ---------------------

# %%
# Analysis 10: use Analysis 3 now include information about police stations (1 column)
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police.csv')
data_df.drop('closest_police_station', axis=1, inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v10 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 10 ---------------")
display(results_v10)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 10 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0   0.8     0.81  0.51  [(lat, 0.008228363), (lng, 0.007836107), (stra...
# 1  0.97     0.72  0.71  [(lat, 0.17095616129739633), (lng, 0.056030768...
# 2  0.83      0.8  0.54  [(lat, 0.18737129719272047), (lng, 0.108278468...
# 3  1.19     0.57   0.9  [(lat, -12.809423981274387), (lng, 8.645998711...
# 4  1.19     0.57   0.9  [(lat, -12.471045180611755), (lng, 8.211630912...
# 5   1.8     0.03  1.42  [(lat, -0.0), (lng, 0.0), (stratum, 0.03519255...
# 6  1.05     0.67  0.73  [(lat, 0.2592645812249711), (lng, 0.0788552791...
# --------------------- Finish ---------------------

# %%
# Analysis 11: use Analysis 3 now include information about schools
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police_schools.csv')
data_df.drop('closest_police_station', axis=1, inplace=True)
data_df.drop('police_stations_within_800m', axis=1, inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v11 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 11 ---------------")
display(results_v11)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 11 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.52  [(lat, 0.007913888), (lng, 0.007282138), (stra...
# 1  0.97     0.72   0.7  [(lat, 0.16309806864317858), (lng, 0.050927574...
# 2  0.83     0.79  0.54  [(lat, 0.15869267222709743), (lng, 0.080185550...
# 3  1.19     0.58   0.9  [(lat, -14.663117498607354), (lng, 10.05404058...
# 4  1.19     0.58   0.9  [(lat, -14.338567427309144), (lng, 9.551449840...
# 5  1.69     0.14  1.33  [(lat, -0.0), (lng, 0.0), (stratum, 0.0), (liv...
# 6  1.08     0.65  0.75  [(lat, 0.1136615373071662), (lng, 0.0605588435...
# --------------------- Finish ---------------------

# %%
# Analysis 12: use Analysis 3 now include information about police stations and schools
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police_schools.csv')
# data_df.drop('closest_police_station', axis=1, inplace=True)
# data_df.drop('police_stations_within_800m', axis=1, inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v12 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 12 ---------------")
display(results_v12)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 12 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.52  [(lat, 0.0076839114), (lng, 0.0069092577), (st...
# 1  0.97     0.72   0.7  [(lat, 0.16008450042186534), (lng, 0.049508751...
# 2  0.83     0.79  0.55  [(lat, 0.14958309867953576), (lng, 0.072154082...
# 3  1.18     0.58  0.89  [(lat, -12.80106326600239), (lng, 9.1131758274...
# 4  1.18     0.58  0.89  [(lat, -12.431716552522598), (lng, 8.618789727...
# 5  1.66     0.17   1.3  [(lat, -0.0), (lng, 0.0), (stratum, 0.0), (liv...
# 6  1.09     0.64  0.75  [(lat, 0.19548557957841126), (lng, 0.078967575...
# --------------------- Finish ---------------------

# %%
# Analysis 13: use Analysis 3 now include information about schools
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police_schools.csv')
data_df.drop('closest_police_station', axis=1, inplace=True)
data_df.drop('police_stations_within_800m', axis=1, inplace=True)
data_df.drop('public_school_in_800m', axis=1, inplace=True)
data_df.drop('private_school_in_800m', axis=1, inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v13 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 13 ---------------")
display(results_v13)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 13 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81      0.8  0.52  [(lat, 0.008096398), (lng, 0.0075676884), (str...
# 1  0.97     0.72  0.71  [(lat, 0.1663404072510946), (lng, 0.0516340368...
# 2  0.83     0.79  0.55  [(lat, 0.16982289495833314), (lng, 0.090819791...
# 3  1.19     0.58   0.9  [(lat, -14.190097521593605), (lng, 9.622362109...
# 4  1.19     0.58   0.9  [(lat, -13.885294745653148), (lng, 9.161481533...
# 5  1.71     0.13  1.35  [(lat, -0.0), (lng, 0.0), (stratum, 0.0), (liv...
# 6  1.07     0.66  0.74  [(lat, 0.2678571153763499), (lng, 0.1092687903...
# --------------------- Finish ---------------------

# %%
# Analysis 14: use Analysis 3 now include information about schools
data_df = pd.read_csv('Data/Raw_data_sales_full_excl_nbrs_incl_police_schools.csv')
data_df.drop('closest_police_station', axis=1, inplace=True)
data_df.drop('police_stations_within_800m', axis=1, inplace=True)
data_df.drop('closest_public_school', axis=1, inplace=True)
data_df.drop('closest_private_school', axis=1, inplace=True)
x_column_names = data_df.drop('price_m2',axis=1).columns.values.tolist()
results_v14 = execute_analysis(data_df, x_column_names)

# %%
print("--------------- Results Analysis 14 ---------------")
display(results_v14)
print("--------------------- Finish ---------------------")
# Out:
# --------------- Results Analysis 14 ---------------
#                      Model                                         Parameters
# 0                  XGBoost  {'learning_rate': 0.01, 'max_depth': 100, 'min...  \
# 1           Gradient Boost  {'learning_rate': 0.1, 'loss': 'squared_error'...
# 2   RandomForest Regressor  {'max_features': 0.6, 'min_samples_leaf': 1, '...
# 3        Lineal Regression                                                 NA
# 4                    Ridge                                                 NA
# 5                    Lasso                                                 NA
# 6  DecissionTree Regressor  {'max_features': 'sqrt', 'min_samples_leaf': 5...
#
#    RMSE R2 Score   MAE                                 Feature Importance
# 0  0.81     0.81  0.51  [(lat, 0.0080469735), (lng, 0.0075356523), (st...
# 1  0.97     0.72  0.71  [(lat, 0.16597058557360803), (lng, 0.054261645...
# 2  0.83      0.8  0.54  [(lat, 0.1746515532364485), (lng, 0.0962208381...
# 3  1.19     0.57   0.9  [(lat, -14.629961116272627), (lng, 9.112025641...
# 4  1.19     0.57   0.9  [(lat, -14.31648705946005), (lng, 8.6555188012...
# 5   1.7     0.13  1.34  [(lat, -0.0), (lng, 0.0), (stratum, 0.0), (liv...
# 6  1.06     0.66  0.74  [(lat, 0.1382309979677474), (lng, 0.0716724604...
# --------------------- Finish ---------------------
